# %%
g_GJ_arr=[0.0, 0.001,0.004,0.008,0.01,0.016,0.02,0.030,0.040,0.06, 0.1]


noise_arr = [2,4,6,8,10,100]

# %%
import numpy as np
gap_junction = np.array([0.0, 0.001, 0.004, 0.008, 0.01, 0.016, 0.02, 0.030, 0.33, 0.040])
synchrony_2 = np.array([54.92, 73.13, 89.31, 89.32, 91.90, 94.44, 94.33, 81.33, 14.35])
synchrony_4 = np.array([29.51, 81.00, 81.96, 90.77, 92.25, 94.78, 94.42, 82.62, 4.5])
synchrony_6 = np.array([19.23, 50.32, 73.02, 86.85, 90.15, 93.65, 93.90,86.71, 92.77])
synchrony_8 = np.array([24.23, 51.07, 65.99, 82.84, 85.737, 91.72, 92.21, 87.32, 92.27])
synchrony_10 = np.array([11.52, 29.92, 65.80, 80.88, 86.19,     , 91.40 ])

# %%
import numpy as np
gap_junction_1 = np.array([0.0, 0.001,0.004,0.008,0.01,0.016,0.02,0.030])
gap_junction = np.array([0.0,0.001,0.003,0.004,0.005,0.008,0.02,0.03])
synchrony = np.array([83.62,84.35,87.8,91.50,86.05,86.23,84.36,81.72])

synchrony_2 = np.array([54.92,73.13,89.31,89.32,91.90,94.44,94.33,81.33,])
synchrony_4 = np.array([29.51, 81.00, 81.96, 90.77, 92.25, 94.78, 94.42, 82.62])
synchrony_6 = np.array([19.23, 50.32, 73.02, 86.85, 90.15, 93.65, 93.90,86.71])
import matplotlib.pyplot as plt
plt.xlabel("Gap Junction Conductance")
plt.ylabel("Measure of synchrony")
z= np.polyfit(gap_junction,synchrony,7)
p= np.poly1d(z)
z2= np.polyfit(gap_junction_1,synchrony_2,4)
p2= np.poly1d(z2)
z4= np.polyfit(gap_junction_1,synchrony_4,3)
p4= np.poly1d(z4)
z6= np.polyfit(gap_junction_1,synchrony_6,3)
p6= np.poly1d(z6)
#plt.ylim(70,100)
plt.xlim(0,0.04)
plt.plot(gap_junction,p(gap_junction),"r-")
plt.plot(gap_junction_1,p2(gap_junction_1),"b-")
plt.plot(gap_junction_1,p4(gap_junction_1),"g-")
#plt.plot(gap_junction_1,p6(gap_junction_1),"y-")
plt.title("Synchrony variation with noise")
plt.legend(["1x","2x","4x"])
plt.show()

# %%
#noise = 1*gwn
import numpy as np
gap_junction = np.array([0.0,0.001,0.003,0.004,0.005,0.008,0.02,0.04,0.05,0.06,0.07,0.08,0.09,0.1,0.16])
synchrony = np.array([83.62,84.35,87.8,91.50,86.05,86.23,84.36,75.83,82.64,76.10,78.35,83,80.5,77,74])

import matplotlib.pyplot as plt
plt.xlabel("Gap Junction Conductance", fontsize = 20)
plt.ylabel("Measure of synchrony", fontsize = 20)
z= np.polyfit(gap_junction,synchrony,6)
p= np.poly1d(z)
plt.ylim(70,100)
#plt.xlim(0,0.04)
plt.scatter(gap_junction,synchrony,color="purple")
#plt.plot(gap_junction,p(gap_junction),"r--")
plt.title("Variation of rhythm synchrony (at low noise)", fontsize = 20)
plt.show()

# %%
#noise = 2*gwn
import numpy as np
gap_junction = np.array([0.0, 0.001,0.004,0.008,0.01,0.016,0.02,0.030,0.040])
synchrony_2 = np.array([54.92,73.13,89.31,89.32,91.90,94.44,94.33,81.33, 14.35])
#0.06 = 91.49
import matplotlib.pyplot as plt
plt.xlabel("Gap Junction Conductance")
plt.ylabel("Synchrony in %")
z2= np.polyfit(gap_junction,synchrony_2,2)
p2= np.poly1d(z2)
#plt.ylim(70,100)
plt.xlim(0,0.04)
plt.scatter(gap_junction,synchrony_2,color="blue")
plt.plot(gap_junction,p2(gap_junction),"b--")
plt.show()

# %%
#noise = 4*gwn
import numpy as np
gap_junction = np.array([0.0, 0.001,0.004,0.008,0.01,0.016,0.02,0.030,0.040])
synchrony_4 = np.array([29.51, 81.00, 81.96, 90.77, 92.25, 94.78, 94.42, 82.62, 4.5])

import matplotlib.pyplot as plt
plt.xlabel("Gap Junction Conductance")
plt.ylabel("Synchrony in %")
z4= np.polyfit(gap_junction,synchrony_4,3)
p4= np.poly1d(z4)
#plt.ylim(70,100)
plt.xlim(0,0.04)
plt.scatter(gap_junction,synchrony_4)
plt.plot(gap_junction,p4(gap_junction),"r--")
plt.show()

# %%
#noise = 6*gwn
import numpy as np
gap_junction_2 = np.array([0.0, 0.001,0.004,0.008,0.01,0.016,0.02,0.030,0.040])
synchrony_6 = np.array([19.23, 50.32, 73.02, 86.85, 90.15, 93.65, 93.90,86.71, 92.77])
z6= np.polyfit(gap_junction_2,synchrony_6,3)
p6= np.poly1d(z6)
import matplotlib.pyplot as plt
plt.xlabel("Gap Junction Conductance")
plt.ylabel("Synchrony in %")

#plt.ylim(70,100)
plt.xlim(0,0.04)
plt.plot(gap_junction_2,p6(gap_junction_2),"r--")
plt.show()

# %%
#noise = 8*gwn
import numpy as np
gap_junction_2 = np.array([0.0, 0.001,0.004,0.008,0.01,0.016,0.02,0.030,0.040])
synchrony_8 = np.array([24.23, 51.07, 65.99, 82.84, 85.737, 91.72, 92.21, 87.32, 92.27])
z8= np.polyfit(gap_junction_2,synchrony_8,3)
p8= np.poly1d(z8)
import matplotlib.pyplot as plt
plt.xlabel("Gap Junction Conductance")
plt.ylabel("Synchrony in %")

#plt.ylim(70,100)
plt.xlim(0,0.04)
plt.plot(gap_junction_2,p8(gap_junction_2),"r--")
plt.scatter(gap_junction_2,synchrony_8,c="r")
plt.show()

# %%
import numpy as np
gap_junction_1 = np.array([0.0, 0.001,0.004,0.008,0.01,0.016,0.02,0.030])
gap_junction = np.array([0.0,0.001,0.003,0.004,0.005,0.008,0.02,0.03])
synchrony = np.array([83.62,84.35,87.8,91.50,86.05,86.23,84.36,81.72])

synchrony_2 = np.array([54.92,73.13,89.31,89.32,91.90,94.44,94.33,81.33])
synchrony_4 = np.array([29.51, 81.00, 81.96, 90.77, 92.25, 94.78, 94.42, 82.62])
synchrony_6 = np.array([19.23, 50.32, 73.02, 86.85, 90.15, 93.65, 93.90,86.71])
synchrony_8 = np.array([24.23, 51.07, 65.99, 82.84, 85.737, 91.72, 92.21, 87.32])
import matplotlib.pyplot as plt
plt.xlabel("Intensity of gap junction coupling", fontsize =20)
plt.ylabel("Measure of synchrony", fontsize = 20)
plt.scatter(gap_junction,synchrony,c="purple",label="1x")
#plt.scatter(gap_junction_1,synchrony_2,c="green",label="2x")
plt.scatter(gap_junction_1,synchrony_4,c="blue",label="4x")
#plt.scatter(gap_junction_1,synchrony_6,c="yellow",label="6x")
plt.scatter(gap_junction_1,synchrony_8,c="red",label="8x")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.title("Synchrony variation", fontsize = 20)
#plt.yticks(fontsize=20)
#plt.xticks(fontsize=20)
plt.xlim(0,0.04)
plt.show()
